# %% [markdown]
# ## Solar Panel Fault Identification
# ### Task Model
# Applied Machine Learning Project <br>
#
# Solar Panel Fault Detection using CNN
#
# **Task description and objectives**
# - The aim of this project is to create a Machine Learning Model that accurately predicts and shows what type of defect a solar panel has, based on pictures of it.
# - It will be a supervised learning model.
# - Supervised: Predict type or presence of defect (classification) based on sensor/thermal/image data.

# %%
# Local changes needed for better visualisation of outputs 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # hides INFO and WARNING logs|

from IPython.display import HTML

HTML('''
<style>
/* for JupyterLab: limit each output pane to 400px tall and add a scrollbar */
.jp-OutputArea-child {
  max-height: 400px;
  overflow-y: auto;
}

/* for classic Jupyter: same idea */
.output_scroll {
  max-height: 400px;
  overflow-y: auto;
}
</style>
''')
# Out:
# <style>
# /* for JupyterLab: limit each output pane to 400px tall and add a scrollbar */
# .jp-OutputArea-child {
#   max-height: 400px;
#   overflow-y: auto;
# }
#
# /* for classic Jupyter: same idea */
# .output_scroll {
#   max-height: 400px;
#   overflow-y: auto;
# }
# </style>

# %%
# Libraries used throughout this script
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import opendatasets as od
import os
from tensorflow.keras import layers, models, optimizers, losses, metrics
import pathlib
from sklearn.model_selection import train_test_split

# %%
# GPU configuration (run in a notebook cell)
print("Built with CUDA:", tf.test.is_built_with_cuda())

build_info = tf.sysconfig.get_build_info()
print("CUDA version (build):", build_info.get("cuda_version"))
print("cuDNN version (build):", build_info.get("cudnn_version"))

gpus = tf.config.list_physical_devices("GPU")
print("GPUs visible to TF:", gpus)
# Out:
# Built with CUDA: True
# CUDA version (build): 12.5.1
# cuDNN version (build): 9
# GPUs visible to TF: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
od.download('https://www.kaggle.com/datasets/pythonafroz/solar-panel-images') # use force=True for forcing the download
data_dir = './solar-panel-images/Faulty_solar_panel'
# Out:
# Skipping, found downloaded files in "./solar-panel-images" (use force=True to force download)

# %%
# 1. List all image paths + labels
data_root = pathlib.Path(data_dir)
all_paths  = list(data_root.glob('*/*.jpg'))
all_labels = [p.parent.name for p in all_paths]

# 2. Train+Val vs. Test (e.g. 80/20)
paths_trainval, paths_test, labels_trainval, labels_test = train_test_split(
    all_paths, all_labels,
    test_size=0.20,
    stratify=all_labels,
    random_state=123
)

# 3. Train vs. Val within the 80%
paths_train, paths_val, labels_train, labels_val = train_test_split(
    paths_trainval, labels_trainval,
    test_size=0.20,  # 20% of 80% = 16% overall
    stratify=labels_trainval,
    random_state=123
)

# 4. Utility to build a tf.data.Dataset from (paths, labels)
def make_ds(paths, labels):
    # map filenames → (image_tensor, label_int)
    path_ds  = tf.data.Dataset.from_tensor_slices([str(p) for p in paths])
    label_to_index = {name:i for i,name in enumerate(class_names)}
    label_ds = tf.data.Dataset.from_tensor_slices([label_to_index[l] for l in labels])
    ds = tf.data.Dataset.zip((path_ds, label_ds))
    def load_and_preprocess(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, img_size)
        return img, label
    return ds.map(load_and_preprocess, num_parallel_calls=AUTOTUNE) \
             .batch(batch_size) \
             .prefetch(AUTOTUNE)

train_ds = make_ds(paths_train, labels_train)
val_ds   = make_ds(paths_val,   labels_val)
test_ds  = make_ds(paths_test,  labels_test)

# %%
# Model definition
# ----------------
# Build a simple CNN using Keras Sequential API. Adjust the number of filters,
# kernel sizes, and dense units as needed for your solar-panel defect task.
num_classes = len(class_names)

model_LeNet = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),    # input layer
    layers.Conv2D(8, kernel_size=5, activation='relu'),  # conv block 1
    layers.MaxPooling2D(pool_size=2),
    layers.Conv2D(16, kernel_size=5, activation='relu'), # conv block 2
    layers.MaxPooling2D(pool_size=2),
    layers.GlobalAveragePooling2D(),                     # global pooling
    layers.Dense(128, activation='relu'),                # fully connected
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes)                            # logits output
])

model_LeNet.summary()  # prints model architecture and parameter counts|
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 240, 240, 8)    │           608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 120, 120, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 116, 116, 16)   │         3,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 58, 58, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 16)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,646 (57.21 KB)
#  Trainable params: 14,646 (57.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model definition
# ----------------
# Build a simple CNN using Keras Sequential API. Adjust the number of filters,
# kernel sizes, and dense units as needed for your solar-panel defect task.
num_classes = len(class_names)

model = models.Sequential([
    layers.Input(shape=(img_size[0], img_size[1], 3)),    # input layer
    layers.Conv2D(64, kernel_size=11, activation='relu'),  # conv block 1
    layers.MaxPooling2D(pool_size=3),
    layers.Conv2D(128, kernel_size=5, activation='relu'),   # conv block 2
    layers.MaxPooling2D(pool_size=3),
    layers.Conv2D(256, kernel_size=3, activation='relu'),
    layers.Conv2D(256, kernel_size=3, activation='relu'),
    layers.Conv2D(256, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=3),                     # global pooling
    layers.Flatten(),
    layers.Dense(512, activation='relu'),                # fully connected
    layers.Dropout(0.5),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')      # logits output
])

model.summary()  # prints model architecture and parameter counts|
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_11 (Conv2D)              │ (None, 234, 234, 64)   │        23,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 78, 78, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 74, 74, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 22, 22, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 20, 20, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 18, 18, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,688,390 (25.51 MB)
#  Trainable params: 6,688,390 (25.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile & train
# ----------------
# Configure the training process: optimizer, loss function, and metrics.
# Then fit the model on `train_ds`, validating on `val_ds`.
epochs = 100

model.compile(
    optimizer=optimizers.Adam(),
    loss=losses.SparseCategoricalCrossentropy(),
    metrics=[metrics.SparseCategoricalAccuracy()]
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=64,
    epochs=epochs
)
# Out:
# Epoch 1/100
# /home/andreibaidoc/miniconda/envs/solar_tf/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 19.6468 - sparse_categorical_accuracy: 0.1527
# 2025-05-22 18:59:38.957681: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng20{k2=8,k3=0} for conv %cudnn-conv-bw-filter.5 = (f32[64,3,11,11]{3,2,1,0}, u8[0]{0}) custom-call(f32[31,3,244,244]{3,2,1,0} %bitcast.8286, f32[31,64,234,234]{3,2,1,0} %bitcast.8653), window={size=11x11}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/sequential_4_1/conv2d_11_1/convolution/Conv2DBackpropFilter" source_file="/home/andreibaidoc/miniconda/envs/solar_tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-05-22 18:59:39.066523: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.195975357s
# Trying algorithm eng20{k2=8,k3=0} for conv %cudnn-conv-bw-filter.5 = (f32[64,3,11,11]{3,2,1,0}, u8[0]{0}) custom-call(f32[31,3,244,244]{3,2,1,0} %bitcast.8286, f32[31,64,234,234]{3,2,1,0} %bitcast.8653), window={size=11x11}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/sequential_4_1/conv2d_11_1/convolution/Conv2DBackpropFilter" source_file="/home/andreibaidoc/miniconda/envs/solar_tf/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - loss: 18.3920 - sparse_categorical_accuracy: 0.1564 - val_loss: 1.7454 - val_sparse_categorical_accuracy: 0.2344
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 1.7550 - sparse_categorical_accuracy: 0.2249 - val_loss: 1.7270 - val_sparse_categorical_accuracy: 0.2344
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.7431 - sparse_categorical_accuracy: 0.2458 - val_loss: 1.7754 - val_sparse_categorical_accuracy: 0.2344
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 1.7707 - sparse_categorical_accuracy: 0.2363 - val_loss: 1.7338 - val_sparse_categorical_accuracy: 0.2344
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.7600 - sparse_categorical_accuracy: 0.2330 - val_loss: 1.7492 - val_sparse_categorical_accuracy: 0.2344
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 1.7459 - sparse_categorical_accuracy: 0.2205 - val_loss: 1.7310 - val_sparse_categorical_accuracy: 0.2344
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7112 - sparse_categorical_accuracy: 0.2378 - val_loss: 1.6531 - val_sparse_categorical_accuracy: 0.3047
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss:
- val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - loss: 1.7173 - sparse_categorical_accuracy: 0.2263 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.7231 - sparse_categorical_accuracy: 0.2285 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 1.7178 - sparse_categorical_accuracy: 0.2499 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 1.7159 - sparse_categorical_accuracy: 0.2438 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.7124 - sparse_categorical_accuracy: 0.2556 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 1.7168 - sparse_categorical_accuracy: 0.2335 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 1.7184 - sparse_categorical_accuracy: 0.2349 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 1.7212 - sparse_categorical_accuracy: 0.2136 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.7152 - sparse_categorical_accuracy: 0.2326 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 1.7203 - sparse_categorical_accuracy: 0.2500 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 1.7136 - sparse_categorical_accuracy: 0.2593 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 1.7170 - sparse_categorical_accuracy: 0.2131 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 1.7207 - sparse_categorical_accuracy: 0.2175 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 1.7147 - sparse_categorical_accuracy: 0.2468 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7201 - sparse_categorical_accuracy: 0.2138 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.7148 - sparse_categorical_accuracy: 0.2155 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - loss: 1.7137 - sparse_categorical_accuracy: 0.2383 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 1.7207 - sparse_categorical_accuracy: 0.2425 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 1.7199 - sparse_categorical_accuracy: 0.2432 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 1.7184 - sparse_categorical_accuracy: 0.2307 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 1.7141 - sparse_categorical_accuracy: 0.2179 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 1.7267 - sparse_categorical_accuracy: 0.2214 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 1.7112 - sparse_categorical_accuracy: 0.2323 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.7174 - sparse_categorical_accuracy: 0.2407 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 1.7196 - sparse_categorical_accuracy: 0.2045 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 1.7171 - sparse_categorical_accuracy: 0.1973 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 1.7227 - sparse_categorical_accuracy: 0.2263 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 1.7131 - sparse_categorical_accuracy: 0.2384 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7172 - sparse_categorical_accuracy: 0.2484 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 1.7146 - sparse_categorical_accuracy: 0.2344 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7222 - sparse_categorical_accuracy: 0.2285 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 1.7187 - sparse_categorical_accuracy: 0.2415 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - loss: 1.7180 - sparse_categorical_accuracy: 0.2442 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7142 - sparse_categorical_accuracy: 0.2566 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.7174 - sparse_categorical_accuracy: 0.2064 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 1.7225 - sparse_categorical_accuracy: 0.2316 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 1.7157 - sparse_categorical_accuracy: 0.2209 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 1.7164 - sparse_categorical_accuracy: 0.2233 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7143 - sparse_categorical_accuracy: 0.2440 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 1.7179 - sparse_categorical_accuracy: 0.2169 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.7201 - sparse_categorical_accuracy: 0.2222 - val_loss: 1.7258 - val_sparse_categorical_accuracy: 0.2344
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.7156 - sparse_categorical_accuracy: 0.2202 - val_loss: 1.7259 - val_sparse_categorical_accuracy: 0.2344

# %%
# Final evaluation on test set
# --------------------------------------------
# Compute loss & accuracy on the held-out test set
# (this data was never used during training or validation)
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test         → Loss: {test_loss:.4f}, Accuracy: {test_acc:.4f}")

# %%
# Plot training & validation accuracy
# ------------------------------------
# Visualize how accuracy evolves over epochs to spot overfitting/underfitting.
plt.figure()
plt.plot(history.history['sparse_categorical_accuracy'], label='train')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Sparse Categorical Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation loss
# --------------------------------
# Show loss curves for train vs. validation to assess convergence.
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Visualize sample predictions
# ----------------------------
# Take one batch from val_ds, run predictions, and display a 4×5 grid of images
# with predicted vs. true labels colored green (correct) or red (incorrect).
plt.figure(figsize=(15, 12))
for images, labels in val_ds.take(1):
    preds = model.predict(images)
    pred_labels = np.argmax(preds, axis=1)
    for i in range(min(20, images.shape[0])):
        ax = plt.subplot(4, 5, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))
        color = 'green' if pred_labels[i] == labels[i] else 'red'
        plt.title(f"P: {class_names[pred_labels[i]]}\nT: {class_names[labels[i]]}", color=color)
        plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
